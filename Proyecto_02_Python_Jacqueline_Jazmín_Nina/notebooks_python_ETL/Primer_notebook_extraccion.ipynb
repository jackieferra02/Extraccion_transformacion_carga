# %% [markdown]
# # **Extracción de los datos**
#
# **Elaborado por:** Jacqueline Fernández, Jazmín Fernández y Nina Odoux.

# %%
# Importación de librería

import pandas as pd

# %%
# Lectura y extracción del csv 'driver_details'

driver_details = pd.read_csv('driver_details.csv')

driver_details
# Out:
#                                 Car         Date             Driver  \
# 0                           Ferrari  21 May 1950     Alberto Ascari
# 1                           Ferrari  04 Jun 1950     Alberto Ascari
# 2                           Ferrari  18 Jun 1950     Alberto Ascari
# 3                           Ferrari  03 Sep 1950     Alberto Ascari
# 4                 Deidt Offenhauser  30 May 1950  Tony Bettenhausen
# ...                             ...          ...                ...
# 19809  Aston Martin Aramco Mercedes  20 Nov 2022       Lance Stroll
# 19810               AlphaTauri RBPT  20 Nov 2022       Yuki Tsunoda
# 19811          Red Bull Racing RBPT  20 Nov 2022     Max Verstappen
# 19812  Aston Martin Aramco Mercedes  20 Nov 2022   Sebastian Vettel
# 19813            Alfa Romeo Ferrari  20 Nov 2022        Guanyu Zhou
#
#              Grand Prix   PTS Race Position  Year
# 0                Monaco   6.0             2  1950
# ...

# %%
# Lectura y extracción del csv 'driver_standings'

driver_standings = pd.read_csv('driver_standings.csv')

driver_standings
# Out:
#      Pos              Driver Nationality                           Car   PTS  \
# 0      1         Nino Farina         ITA                    Alfa Romeo  30.0
# 1      2  Juan Manuel Fangio         ARG                    Alfa Romeo  27.0
# 2      3       Luigi Fagioli         ITA                    Alfa Romeo  24.0
# 3      4        Louis Rosier         FRA                   Talbot-Lago  13.0
# 4      5      Alberto Ascari         ITA                       Ferrari  11.0
# ...   ..                 ...         ...                           ...   ...
# 1613  18         Zhou Guanyu         CHN            Alfa Romeo Ferrari   6.0
# 1614  19     Alexander Albon         THA             Williams Mercedes   4.0
# 1615  20     Nicholas Latifi         CAN             Williams Mercedes   2.0
# 1616  21       Nyck De Vries         NED             Williams Mercedes   2.0
# 1617  22     Nico Hulkenberg         GER  Aston Martin Aramco Mercedes   0.0
#
#      DriverCode  Year
# ...

# %%
# Lectura y extracción del csv 'race_details'

race_details = pd.read_csv('race_details.csv')

race_details
# Out:
#       Pos  No                 Driver                Car  Laps Time/Retired  \
# 0       1   2            Nino Farina         Alfa Romeo  70.0  2:13:23.600
# 1       2   3          Luigi Fagioli         Alfa Romeo  70.0      +2.600s
# 2       3   4            Reg Parnell         Alfa Romeo  70.0     +52.000s
# 3       4  14  Yves Giraud-Cabantous        Talbot-Lago  68.0      +2 laps
# 4       5  15           Louis Rosier        Talbot-Lago  68.0      +2 laps
# ...    ..  ..                    ...                ...   ...          ...
# 23973  16  47        Mick Schumacher       Haas Ferrari  57.0       +1 lap
# 23974  17  20        Kevin Magnussen       Haas Ferrari  57.0       +1 lap
# 23975  18  44         Lewis Hamilton           Mercedes  55.0          DNF
# 23976  19   6        Nicholas Latifi  Williams Mercedes  55.0          DNF
# 23977  NC  14        Fernando Alonso     Alpine Renault  27.0          DNF
#
#        PTS  Year     Grand Prix       Detail DriverCode
# ...

# %%
# Verificar el número de registros en cada DataFrame

print(f"Registros en driver_details: {len(driver_details)}")
print(f"Registros en driver_standings: {len(driver_standings)}")
print(f"Registros en race_details: {len(race_details)}")
# Out:
# Registros en driver_details: 19814
# Registros en driver_standings: 1618
# Registros en race_details: 23978

# %% [markdown]
# Durante el proceso de extracción, se verificó que los archivos CSV se cargaron correctamente, y se confirmó que la cantidad de registros coincide con los datos esperados. Los detalles de los registros aseguran que la carga de datos se realizó de manera precisa, permitiendo proceder con el análisis con confianza en la integridad y coherencia de la información.
